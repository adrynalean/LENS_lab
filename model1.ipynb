# %%
# Import dependencies
import cv2
import numpy as np
from ultralytics import YOLO

print("Dependencies imported successfully.")
# Out:
# Dependencies imported successfully.

# %%
# Load YOLO model
model = YOLO('yolov8n.pt')  # Replace with custom weights if available
print("YOLO model loaded successfully.")
# Out:
# YOLO model loaded successfully.

# %%
# Initialize webcam
cap = cv2.VideoCapture(0)  # Use device index (0 is the default webcam)

# Check if the webcam is accessible
if not cap.isOpened():
    print("Error: Could not access the webcam.")
else:
    print("Webcam is ready.")
# Out:
# Webcam is ready.

# %%
# Function to calculate bounding box area
def calculate_area(box):
    """Calculate the area of a bounding box."""
    x1, y1, x2, y2 = box
    return (x2 - x1) * (y2 - y1)

# Function to check if an object is static
def is_static(previous_area, current_area, threshold=0.1):
    """
    Determine if an object is static based on area change.
    Args:
        previous_area (float): The bounding box area in the previous frame.
        current_area (float): The bounding box area in the current frame.
        threshold (float): The percentage of area change considered static.
    Returns:
        bool: True if the object is static, False otherwise.
    """
    if previous_area == 0:
        return False
    change = abs(current_area - previous_area) / previous_area
    return change < threshold

# Initialize variables
tracked_objects = {}  # Track bounding box areas across frames
size_increase_threshold = 1.4  # Trigger alert for 40% increase

# %%
# Function to calculate proximity
def calculate_proximity(prev_box, curr_box):
    """
    Calculate the proximity of an object based on bounding box size.
    Args:
        prev_box (tuple): Previous bounding box (x1, y1, x2, y2).
        curr_box (tuple): Current bounding box (x1, y1, x2, y2).
    Returns:
        float: Proximity value normalized between 0 and 1.
    """
    prev_area = (prev_box[2] - prev_box[0]) * (prev_box[3] - prev_box[1])
    curr_area = (curr_box[2] - curr_box[0]) * (curr_box[3] - curr_box[1])
    if prev_area == 0:
        return 0
    return min(curr_area / prev_area, 1.0)  # Normalize to 0-1

# Initialize variables
prev_boxes = {}
initial_box_areas = {}  # Tracks the initial size of objects
size_increase_threshold = 1.2  # Trigger alert for 20% increase in size

print("Helper functions and variables initialized.")
# Out:
# Helper functions and variables initialized.

# %%
try:
    while True:
        ret, frame = cap.read()
        if not ret:
            print("Error: Could not retrieve frame from webcam.")
            break

        # Run YOLO detection
        results = model(frame)

        curr_boxes = {}
        for result in results:
            for bbox, cls in zip(result.boxes.xyxy, result.boxes.cls):
                x1, y1, x2, y2 = map(int, bbox[:4])
                label = result.names[int(cls)]

                # Calculate the current bounding box area
                curr_area = calculate_area((x1, y1, x2, y2))

                # Check if this is a new object
                if label not in tracked_objects:
                    tracked_objects[label] = curr_area
                    print(f"New object detected: {label}")
                    continue

                # Check if the object is static
                previous_area = tracked_objects[label]
                if is_static(previous_area, curr_area):
                    proximity = 0  # Static objects are safe
                    color = (0, 255, 0)  # Green for static objects
                else:
                    # Check if the object is moving closer
                    size_increase = curr_area / tracked_objects[label]
                    if size_increase > size_increase_threshold:
                        proximity = min(size_increase - 1, 1.0)  # Normalize to 0 to 1
                        print(f"Warning: {label} Approaching! Proximity: {proximity:.2f}")
                        color = (0, 0, 255)  # Red for dynamic approaching objects
                    else:
                        proximity = 0  # Safe proximity
                        color = (0, 255, 0)  # Green for safe objects

                # Update the tracked object
                tracked_objects[label] = curr_area

                # Draw bounding box and proximity info
                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                cv2.putText(frame, f'{label}: {proximity:.2f}', (x1, y1 - 10), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

        # Display the live webcam feed
        cv2.imshow("YOLOv8 Live Detection", frame)

        # Exit the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            print("Exiting live feed...")
            break
except KeyboardInterrupt:
    print("Live feed interrupted.")
# Out:
# 0: 480x640 1 person, 1 chair, 1 couch, 49.6ms
# Speed: 3.0ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# New object detected: person
# New object detected: chair
# New object detected: couch
#
# 0: 480x640 1 person, 1 chair, 1 bed, 1 laptop, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# New object detected: laptop
# New object detected: bed
#
# 0: 480x640 1 person, 2 chairs, 43.6ms
# Speed: 2.2ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 42.6ms
# Speed: 2.0ms preprocess, 42.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 44.6ms
# Speed: 2.0ms preprocess, 44.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 41.1ms
# Speed: 2.5ms preprocess, 41.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 41.2ms
# Speed: 1.5ms preprocess, 41.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: laptop Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 42.4ms
# Speed: 2.0ms preprocess, 42.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 39.2ms
# Speed: 2.0ms preprocess, 39.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 bed, 41.3ms
# Speed: 1.5ms preprocess, 41.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 laptop, 41.1ms
# Speed: 2.0ms preprocess, 41.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 1 bed, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
# Warning: bed Approaching! Proximity: 0.99
#
# 0: 480x640 1 person, 1 chair, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 45.4ms
# Speed: 2.0ms preprocess, 45.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 45.1ms
# Speed: 2.5ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: laptop Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 46.1ms
# Speed: 2.5ms preprocess, 46.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 44.6ms
# Speed: 2.5ms preprocess, 44.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 49.1ms
# Speed: 2.0ms preprocess, 49.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 50.6ms
# Speed: 2.0ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 70.1ms
# Speed: 2.0ms preprocess, 70.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 42.3ms
# Speed: 2.0ms preprocess, 42.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 48.1ms
# Speed: 2.5ms preprocess, 48.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 45.9ms
# Speed: 2.5ms preprocess, 45.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 46.6ms
# Speed: 2.0ms preprocess, 46.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 47.1ms
# Speed: 2.0ms preprocess, 47.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 48.6ms
# Speed: 2.0ms preprocess, 48.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 46.7ms
# Speed: 2.0ms preprocess, 46.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 46.3ms
# Speed: 2.0ms preprocess, 46.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 44.1ms
# Speed: 2.5ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 50.1ms
# Speed: 2.0ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 47.6ms
# Speed: 2.0ms preprocess, 47.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 52.6ms
# Speed: 2.0ms preprocess, 52.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 50.6ms
# Speed: 2.0ms preprocess, 50.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 51.6ms
# Speed: 2.0ms preprocess, 51.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 48.1ms
# Speed: 3.0ms preprocess, 48.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 chair, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 2 chairs, 1 bed, 47.5ms
# Speed: 2.0ms preprocess, 47.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 1 bed, 50.1ms
# Speed: 2.5ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
# Warning: bed Approaching! Proximity: 0.87
#
# 0: 480x640 1 person, 1 chair, 50.6ms
# Speed: 2.0ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 47.6ms
# Speed: 3.0ms preprocess, 47.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 47.1ms
# Speed: 2.5ms preprocess, 47.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 47.2ms
# Speed: 1.0ms preprocess, 47.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 44.0ms
# Speed: 3.0ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 60.6ms
# Speed: 4.5ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 46.6ms
# Speed: 2.0ms preprocess, 46.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 44.1ms
# Speed: 2.5ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 48.6ms
# Speed: 2.5ms preprocess, 48.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 49.1ms
# Speed: 2.0ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 49.8ms
# Speed: 3.0ms preprocess, 49.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 53.9ms
# Speed: 3.0ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 46.5ms
# Speed: 2.0ms preprocess, 46.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 46.6ms
# Speed: 3.0ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 bed, 48.1ms
# Speed: 1.5ms preprocess, 48.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
# Warning: bed Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 1 bed, 42.5ms
# Speed: 2.0ms preprocess, 42.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 42.6ms
# Speed: 2.0ms preprocess, 42.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 40.6ms
# Speed: 2.0ms preprocess, 40.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 40.6ms
# Speed: 3.5ms preprocess, 40.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 41.9ms
# Speed: 2.5ms preprocess, 41.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 43.0ms
# Speed: 2.0ms preprocess, 43.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 43.7ms
# Speed: 2.0ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 45.0ms
# Speed: 2.0ms preprocess, 45.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: laptop Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 1 bed, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 41.1ms
# Speed: 2.0ms preprocess, 41.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 51.1ms
# Speed: 2.0ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 book, 41.6ms
# Speed: 2.0ms preprocess, 41.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# New object detected: book
#
# 0: 480x640 1 person, 2 chairs, 38.3ms
# Speed: 2.0ms preprocess, 38.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 chair, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 41.1ms
# Speed: 1.5ms preprocess, 41.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 1 bed, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bed Approaching! Proximity: 0.76
#
# 0: 480x640 1 person, 1 chair, 45.1ms
# Speed: 2.5ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 41.2ms
# Speed: 2.5ms preprocess, 41.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 41.5ms
# Speed: 2.0ms preprocess, 41.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 41.1ms
# Speed: 2.0ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 48.1ms
# Speed: 2.0ms preprocess, 48.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 41.7ms
# Speed: 1.5ms preprocess, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 42.1ms
# Speed: 1.0ms preprocess, 42.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 40.7ms
# Speed: 2.0ms preprocess, 40.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 39.1ms
# Speed: 2.0ms preprocess, 39.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 41.1ms
# Speed: 2.0ms preprocess, 41.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 1 couch, 41.6ms
# Speed: 2.0ms preprocess, 41.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 42.6ms
# Speed: 2.0ms preprocess, 42.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 42.9ms
# Speed: 2.0ms preprocess, 42.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 44.6ms
# Speed: 3.0ms preprocess, 44.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 47.7ms
# Speed: 2.0ms preprocess, 47.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 1 laptop, 48.6ms
# Speed: 3.5ms preprocess, 48.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 46.0ms
# Speed: 2.5ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 42.4ms
# Speed: 2.0ms preprocess, 42.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 43.6ms
# Speed: 2.0ms preprocess, 43.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 couch, 40.6ms
# Speed: 2.0ms preprocess, 40.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 44.3ms
# Speed: 2.0ms preprocess, 44.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 45.8ms
# Speed: 2.0ms preprocess, 45.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 44.1ms
# Speed: 2.5ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 44.1ms
# Speed: 3.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 43.0ms
# Speed: 1.5ms preprocess, 43.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 56.7ms
# Speed: 2.0ms preprocess, 56.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 54.7ms
# Speed: 2.5ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 50.3ms
# Speed: 2.0ms preprocess, 50.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 50.5ms
# Speed: 2.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 1 laptop, 53.0ms
# Speed: 1.6ms preprocess, 53.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bed Approaching! Proximity: 0.59
#
# 0: 480x640 1 person, 2 chairs, 1 bed, 43.7ms
# Speed: 2.5ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 1 bed, 41.6ms
# Speed: 1.5ms preprocess, 41.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 41.8ms
# Speed: 2.0ms preprocess, 41.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 45.0ms
# Speed: 2.0ms preprocess, 45.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 50.7ms
# Speed: 2.0ms preprocess, 50.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 1 bed, 68.5ms
# Speed: 2.0ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 42.5ms
# Speed: 2.5ms preprocess, 42.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 bed, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 40.1ms
# Speed: 2.0ms preprocess, 40.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 chair, 1 couch, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 49.4ms
# Speed: 2.0ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 45.5ms
# Speed: 2.0ms preprocess, 45.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 45.7ms
# Speed: 2.0ms preprocess, 45.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 44.6ms
# Speed: 2.0ms preprocess, 44.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bed Approaching! Proximity: 0.70
#
# 0: 480x640 1 person, 1 chair, 41.6ms
# Speed: 1.0ms preprocess, 41.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 41.7ms
# Speed: 2.0ms preprocess, 41.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 40.7ms
# Speed: 2.5ms preprocess, 40.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 45.4ms
# Speed: 2.2ms preprocess, 45.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 45.9ms
# Speed: 2.0ms preprocess, 45.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 46.0ms
# Speed: 2.0ms preprocess, 46.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 43.6ms
# Speed: 2.5ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 43.7ms
# Speed: 2.0ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 1 laptop, 45.4ms
# Speed: 2.0ms preprocess, 45.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: laptop Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 2 chairs, 1 bed, 1 laptop, 45.6ms
# Speed: 2.0ms preprocess, 45.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 chair, 41.7ms
# Speed: 2.0ms preprocess, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 66.1ms
# Speed: 1.0ms preprocess, 66.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 47.1ms
# Speed: 2.0ms preprocess, 47.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 47.9ms
# Speed: 2.0ms preprocess, 47.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 chair, 40.2ms
# Speed: 1.0ms preprocess, 40.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 43.6ms
# Speed: 2.0ms preprocess, 43.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 chair, 49.1ms
# Speed: 2.2ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 45.6ms
# Speed: 2.0ms preprocess, 45.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: bed Approaching! Proximity: 0.77
#
# 0: 480x640 2 persons, 1 chair, 43.2ms
# Speed: 2.0ms preprocess, 43.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 bed, 41.6ms
# Speed: 1.0ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 42.6ms
# Speed: 2.5ms preprocess, 42.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.39
#
# 0: 480x640 3 persons, 1 chair, 1 bed, 46.9ms
# Speed: 2.0ms preprocess, 46.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 46.6ms
# Speed: 2.4ms preprocess, 46.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 4 persons, 46.1ms
# Speed: 2.0ms preprocess, 46.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 3 persons, 43.5ms
# Speed: 2.0ms preprocess, 43.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 3 persons, 41.6ms
# Speed: 2.1ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 3 persons, 1 chair, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 3 persons, 48.7ms
# Speed: 2.0ms preprocess, 48.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 3 persons, 44.8ms
# Speed: 2.0ms preprocess, 44.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 3 persons, 45.8ms
# Speed: 2.0ms preprocess, 45.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 4 persons, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 4 persons, 52.6ms
# Speed: 2.0ms preprocess, 52.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 45.1ms
# Speed: 2.0ms preprocess, 45.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 4 persons, 1 skateboard, 41.6ms
# Speed: 2.0ms preprocess, 41.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 1.00
# New object detected: skateboard
#
# 0: 480x640 2 persons, 1 bed, 1 laptop, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: laptop Approaching! Proximity: 1.00
# Warning: bed Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 cat, 45.7ms
# Speed: 2.0ms preprocess, 45.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.80
# New object detected: cat
#
# 0: 480x640 2 persons, 1 cup, 46.6ms
# Speed: 2.0ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# New object detected: cup
#
# 0: 480x640 3 persons, 50.6ms
# Speed: 1.5ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 42.6ms
# Speed: 2.0ms preprocess, 42.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 4 persons, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 cup, 1 bed, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 44.9ms
# Speed: 2.0ms preprocess, 44.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 48.1ms
# Speed: 2.0ms preprocess, 48.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 45.1ms
# Speed: 1.5ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 knife, 1 chair, 47.6ms
# Speed: 2.0ms preprocess, 47.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# New object detected: knife
#
# 0: 480x640 1 person, 2 knifes, 1 chair, 50.6ms
# Speed: 2.0ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 knife, 1 chair, 46.1ms
# Speed: 2.5ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 42.1ms
# Speed: 1.0ms preprocess, 42.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 knife, 1 chair, 1 couch, 46.1ms
# Speed: 2.0ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 knife, 1 chair, 47.6ms
# Speed: 2.0ms preprocess, 47.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 61.1ms
# Speed: 2.0ms preprocess, 61.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 43.1ms
# Speed: 1.5ms preprocess, 43.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 40.7ms
# Speed: 3.0ms preprocess, 40.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 46.2ms
# Speed: 2.0ms preprocess, 46.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 4 persons, 1 chair, 48.6ms
# Speed: 1.5ms preprocess, 48.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 knife, 1 chair, 48.2ms
# Speed: 2.0ms preprocess, 48.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 knife, 2 chairs, 1 laptop, 42.6ms
# Speed: 2.0ms preprocess, 42.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 40.6ms
# Speed: 2.0ms preprocess, 40.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 3 persons, 1 chair, 42.6ms
# Speed: 1.5ms preprocess, 42.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.82
#
# 0: 480x640 2 persons, 1 chair, 1 couch, 52.6ms
# Speed: 3.5ms preprocess, 52.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 0.78
#
# 0: 480x640 2 persons, 1 chair, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.88
#
# 0: 480x640 2 persons, 1 chair, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.78
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bed Approaching! Proximity: 0.67
# Warning: person Approaching! Proximity: 0.81
#
# 0: 480x640 1 person, 1 chair, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 42.1ms
# Speed: 1.5ms preprocess, 42.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.75
#
# 0: 480x640 1 person, 1 chair, 43.3ms
# Speed: 2.0ms preprocess, 43.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 1 chair, 41.2ms
# Speed: 2.0ms preprocess, 41.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 44.6ms
# Speed: 2.0ms preprocess, 44.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 couch, 41.9ms
# Speed: 2.0ms preprocess, 41.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.59
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 40.9ms
# Speed: 1.5ms preprocess, 40.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: laptop Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 0.53
#
# 0: 480x640 1 person, 1 chair, 61.1ms
# Speed: 1.5ms preprocess, 61.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 43.6ms
# Speed: 2.0ms preprocess, 43.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.60
#
# 0: 480x640 2 persons, 1 chair, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.54
#
# 0: 480x640 2 persons, 1 chair, 42.6ms
# Speed: 2.0ms preprocess, 42.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 0.57
#
# 0: 480x640 2 persons, 1 chair, 40.1ms
# Speed: 2.0ms preprocess, 40.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.46
#
# 0: 480x640 2 persons, 1 chair, 46.6ms
# Speed: 2.0ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 43.1ms
# Speed: 2.0ms preprocess, 43.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 47.1ms
# Speed: 1.5ms preprocess, 47.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 couch, 43.1ms
# Speed: 2.0ms preprocess, 43.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 45.1ms
# Speed: 2.0ms preprocess, 45.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 1 bed, 39.0ms
# Speed: 2.5ms preprocess, 39.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.56
#
# 0: 480x640 2 persons, 1 chair, 1 couch, 43.1ms
# Speed: 2.0ms preprocess, 43.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.22
#
# 0: 480x640 2 persons, 1 chair, 43.1ms
# Speed: 1.0ms preprocess, 43.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.56
#
# 0: 480x640 2 persons, 1 chair, 1 couch, 45.6ms
# Speed: 2.0ms preprocess, 45.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 42.2ms
# Speed: 2.0ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.82
#
# 0: 480x640 2 persons, 1 chair, 43.3ms
# Speed: 2.0ms preprocess, 43.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 0.81
#
# 0: 480x640 2 persons, 2 chairs, 41.6ms
# Speed: 1.0ms preprocess, 41.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.62
#
# 0: 480x640 3 persons, 1 chair, 1 couch, 58.1ms
# Speed: 1.0ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 0.69
#
# 0: 480x640 2 persons, 1 chair, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 3 persons, 1 chair, 38.6ms
# Speed: 1.5ms preprocess, 38.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.74
#
# 0: 480x640 2 persons, 1 chair, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.55
#
# 0: 480x640 2 persons, 1 knife, 1 chair, 43.3ms
# Speed: 2.0ms preprocess, 43.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.68
#
# 0: 480x640 2 persons, 1 chair, 1 couch, 45.8ms
# Speed: 2.0ms preprocess, 45.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.59
#
# 0: 480x640 2 persons, 1 chair, 43.6ms
# Speed: 2.0ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.55
#
# 0: 480x640 1 person, 1 chair, 46.6ms
# Speed: 1.0ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 48.8ms
# Speed: 2.6ms preprocess, 48.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 49.6ms
# Speed: 3.0ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 46.2ms
# Speed: 2.0ms preprocess, 46.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 47.1ms
# Speed: 2.0ms preprocess, 47.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 50.6ms
# Speed: 2.0ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 54.7ms
# Speed: 3.0ms preprocess, 54.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 couch, 52.1ms
# Speed: 3.0ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 1 bed, 53.6ms
# Speed: 3.5ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
# Warning: bed Approaching! Proximity: 0.71
#
# 0: 480x640 2 persons, 1 chair, 1 couch, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 57.2ms
# Speed: 3.0ms preprocess, 57.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 67.1ms
# Speed: 2.0ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 79.7ms
# Speed: 4.5ms preprocess, 79.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 58.1ms
# Speed: 2.5ms preprocess, 58.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 47.4ms
# Speed: 3.0ms preprocess, 47.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 53.4ms
# Speed: 2.0ms preprocess, 53.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 42.6ms
# Speed: 2.5ms preprocess, 42.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 49.8ms
# Speed: 2.0ms preprocess, 49.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 45.1ms
# Speed: 2.0ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 tv, 46.1ms
# Speed: 3.0ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# New object detected: tv
#
# 0: 480x640 1 person, 1 chair, 1 couch, 46.1ms
# Speed: 2.5ms preprocess, 46.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.79
#
# 0: 480x640 1 person, 1 chair, 1 bed, 44.1ms
# Speed: 3.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 46.6ms
# Speed: 2.0ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 47.2ms
# Speed: 2.0ms preprocess, 47.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 46.5ms
# Speed: 2.0ms preprocess, 46.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 42.5ms
# Speed: 2.0ms preprocess, 42.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bed Approaching! Proximity: 0.81
#
# 0: 480x640 1 person, 1 chair, 1 couch, 43.1ms
# Speed: 2.0ms preprocess, 43.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 42.6ms
# Speed: 1.0ms preprocess, 42.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 40.6ms
# Speed: 2.0ms preprocess, 40.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 64.1ms
# Speed: 2.0ms preprocess, 64.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 41.6ms
# Speed: 2.0ms preprocess, 41.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.23
#
# 0: 480x640 1 person, 1 chair, 1 couch, 43.8ms
# Speed: 2.0ms preprocess, 43.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 2 beds, 49.1ms
# Speed: 1.5ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 41.3ms
# Speed: 2.0ms preprocess, 41.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 42.2ms
# Speed: 2.0ms preprocess, 42.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 41.6ms
# Speed: 2.0ms preprocess, 41.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 47.9ms
# Speed: 2.0ms preprocess, 47.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 37.1ms
# Speed: 2.0ms preprocess, 37.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 44.9ms
# Speed: 2.0ms preprocess, 44.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# New object detected: bottle
#
# 0: 480x640 1 person, 1 chair, 1 couch, 1 bed, 41.1ms
# Speed: 2.0ms preprocess, 41.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bed Approaching! Proximity: 0.80
#
# 0: 480x640 1 person, 1 chair, 41.7ms
# Speed: 2.0ms preprocess, 41.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 1 couch, 43.6ms
# Speed: 2.0ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bottle Approaching! Proximity: 0.72
#
# 0: 480x640 1 person, 1 chair, 1 couch, 40.6ms
# Speed: 2.5ms preprocess, 40.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 1 bed, 44.6ms
# Speed: 2.0ms preprocess, 44.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bottle Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 41.1ms
# Speed: 1.2ms preprocess, 41.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 couch, 62.1ms
# Speed: 1.0ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 1 bed, 47.6ms
# Speed: 2.0ms preprocess, 47.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: bed Approaching! Proximity: 0.82
#
# 0: 480x640 1 person, 1 chair, 1 couch, 45.1ms
# Speed: 2.0ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 44.5ms
# Speed: 2.0ms preprocess, 44.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 45.6ms
# Speed: 2.0ms preprocess, 45.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 1 couch, 48.3ms
# Speed: 2.0ms preprocess, 48.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 45.0ms
# Speed: 2.0ms preprocess, 45.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 1 couch, 43.6ms
# Speed: 2.0ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 1 bed, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bottle Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 41.0ms
# Speed: 2.5ms preprocess, 41.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bottle Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 1 couch, 42.4ms
# Speed: 2.0ms preprocess, 42.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 bottles, 1 chair, 1 bed, 39.0ms
# Speed: 2.1ms preprocess, 39.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bottle Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 42.1ms
# Speed: 2.0ms preprocess, 42.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 1 bed, 39.1ms
# Speed: 2.0ms preprocess, 39.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 41.2ms
# Speed: 2.0ms preprocess, 41.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 42.5ms
# Speed: 2.0ms preprocess, 42.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 65.1ms
# Speed: 1.0ms preprocess, 65.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 43.7ms
# Speed: 2.0ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.27
#
# 0: 480x640 1 person, 1 chair, 48.1ms
# Speed: 2.0ms preprocess, 48.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 couch, 42.5ms
# Speed: 2.0ms preprocess, 42.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 laptop, 47.1ms
# Speed: 2.0ms preprocess, 47.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 42.2ms
# Speed: 2.0ms preprocess, 42.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 41.6ms
# Speed: 2.5ms preprocess, 41.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 41.7ms
# Speed: 1.0ms preprocess, 41.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.88
#
# 0: 480x640 1 person, 1 chair, 1 bed, 1 laptop, 41.1ms
# Speed: 1.5ms preprocess, 41.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 1 laptop, 42.6ms
# Speed: 2.5ms preprocess, 42.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 40.0ms
# Speed: 1.5ms preprocess, 40.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 39.0ms
# Speed: 2.0ms preprocess, 39.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 1 chair, 42.6ms
# ...
# Speed: 2.0ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bed, 48.6ms
# Speed: 2.0ms preprocess, 48.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 45.2ms
# Speed: 2.1ms preprocess, 45.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bed Approaching! Proximity: 0.69
#
# 0: 480x640 3 persons, 1 chair, 1 bed, 47.0ms
# Speed: 2.0ms preprocess, 47.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.49
#
# 0: 480x640 3 persons, 1 chair, 1 bed, 45.1ms
# Speed: 2.0ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.46
# Warning: person Approaching! Proximity: 0.49
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 1 cell phone, 47.6ms
# Speed: 2.0ms preprocess, 47.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: cell phone Approaching! Proximity: 0.24
# Warning: person Approaching! Proximity: 0.44
# Warning: person Approaching! Proximity: 0.53
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 1 cell phone, 43.1ms
# Speed: 3.0ms preprocess, 43.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.53
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 47.2ms
# Speed: 2.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.45
#
# 0: 480x640 2 persons, 1 cell phone, 46.1ms
# Speed: 2.0ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bed, 1 cell phone, 59.6ms
# Speed: 2.0ms preprocess, 59.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.35
#
# 0: 480x640 2 persons, 1 bed, 1 cell phone, 44.8ms
# Speed: 2.0ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.36
#
# 0: 480x640 1 person, 1 cell phone, 43.1ms
# Speed: 2.0ms preprocess, 43.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.41
#
# 0: 480x640 1 person, 1 cell phone, 41.6ms
# Speed: 2.5ms preprocess, 41.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 45.1ms
# Speed: 2.0ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 42.7ms
# Speed: 1.0ms preprocess, 42.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.32
#
# 0: 480x640 1 person, 2 chairs, 1 bed, 1 laptop, 1 cell phone, 43.1ms
# Speed: 2.0ms preprocess, 43.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.25
#
# 0: 480x640 3 persons, 1 chair, 2 beds, 1 cell phone, 40.6ms
# Speed: 2.0ms preprocess, 40.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 0.82
#
# 0: 480x640 3 persons, 1 chair, 1 bed, 1 laptop, 1 cell phone, 41.6ms
# Speed: 2.0ms preprocess, 41.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bed Approaching! Proximity: 0.58
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 1 bed, 42.7ms
# Speed: 2.0ms preprocess, 42.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.55
#
# 0: 480x640 3 persons, 1 chair, 1 bed, 42.6ms
# Speed: 2.5ms preprocess, 42.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.55
#
# 0: 480x640 2 persons, 2 chairs, 2 beds, 43.6ms
# Speed: 2.0ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.42
# Warning: bed Approaching! Proximity: 0.56
#
# 0: 480x640 3 persons, 1 chair, 1 bed, 1 laptop, 1 cell phone, 39.7ms
# Speed: 2.0ms preprocess, 39.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.31
# Warning: chair Approaching! Proximity: 0.90
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 1 cell phone, 39.7ms
# Speed: 2.0ms preprocess, 39.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 1 cell phone, 46.1ms
# Speed: 2.0ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 1 cell phone, 62.1ms
# Speed: 2.0ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 2 chairs, 2 beds, 1 cell phone, 47.1ms
# Speed: 2.0ms preprocess, 47.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: bed Approaching! Proximity: 0.53
#
# 0: 480x640 2 persons, 2 chairs, 1 bed, 1 cell phone, 42.8ms
# Speed: 2.5ms preprocess, 42.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.46
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 chair, 1 cell phone, 42.6ms
# Speed: 2.5ms preprocess, 42.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.46
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 1 laptop, 1 cell phone, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.48
# Warning: bed Approaching! Proximity: 0.66
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 1 laptop, 1 cell phone, 40.1ms
# Speed: 2.0ms preprocess, 40.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.45
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 1 laptop, 1 cell phone, 39.1ms
# Speed: 2.0ms preprocess, 39.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.45
#
# 0: 480x640 3 persons, 1 bed, 1 laptop, 41.1ms
# Speed: 1.5ms preprocess, 41.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.50
# Warning: laptop Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 2 beds, 39.6ms
# Speed: 3.5ms preprocess, 39.6ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 2 beds, 43.1ms
# Speed: 2.0ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bed Approaching! Proximity: 0.62
#
# 0: 480x640 2 persons, 1 bed, 1 cell phone, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: cell phone Approaching! Proximity: 1.00
# Warning: bed Approaching! Proximity: 0.68
#
# 0: 480x640 2 persons, 1 chair, 2 beds, 1 cell phone, 39.1ms
# Speed: 4.0ms preprocess, 39.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 chair, 2 beds, 1 cell phone, 38.6ms
# Speed: 2.0ms preprocess, 38.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: bed Approaching! Proximity: 0.76
#
# 0: 480x640 3 persons, 1 chair, 2 beds, 1 cell phone, 43.6ms
# Speed: 2.0ms preprocess, 43.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 1.00
# Warning: bed Approaching! Proximity: 0.74
#
# 0: 480x640 3 persons, 1 chair, 2 beds, 1 cell phone, 62.6ms
# Speed: 2.0ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 1.00
# Warning: bed Approaching! Proximity: 0.74
#
# 0: 480x640 1 chair, 1 bed, 40.6ms
# Speed: 2.0ms preprocess, 40.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 37.6ms
# Speed: 2.0ms preprocess, 37.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 42.8ms
# Speed: 2.0ms preprocess, 42.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 44.6ms
# Speed: 2.0ms preprocess, 44.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 chairs, 1 bed, 43.7ms
# Speed: 2.0ms preprocess, 43.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.32
#
# 0: 480x640 2 persons, 2 chairs, 1 bed, 43.5ms
# Speed: 2.0ms preprocess, 43.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 3 persons, 1 chair, 1 bed, 39.5ms
# Speed: 2.5ms preprocess, 39.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 0.68
# Warning: chair Approaching! Proximity: 1.00
# Warning: bed Approaching! Proximity: 0.24
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 2 chairs, 49.1ms
# Speed: 2.5ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 1 laptop, 42.5ms
# Speed: 2.5ms preprocess, 42.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 2 chairs, 1 bed, 1 laptop, 40.6ms
# Speed: 1.0ms preprocess, 40.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 43.3ms
# Speed: 1.5ms preprocess, 43.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 1 bed, 43.2ms
# Speed: 2.0ms preprocess, 43.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 47.8ms
# Speed: 2.0ms preprocess, 47.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 42.0ms
# Speed: 2.3ms preprocess, 42.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 1 bed, 44.5ms
# Speed: 2.5ms preprocess, 44.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 bed, 61.6ms
# Speed: 2.5ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bed Approaching! Proximity: 0.94
#
# 0: 480x640 1 person, 1 chair, 44.1ms
# Speed: 1.5ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 45.1ms
# Speed: 2.0ms preprocess, 45.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 42.9ms
# Speed: 2.0ms preprocess, 42.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 43.5ms
# Speed: 1.3ms preprocess, 43.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 40.6ms
# Speed: 2.0ms preprocess, 40.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 43.6ms
# Speed: 2.0ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 bed, 42.0ms
# Speed: 2.0ms preprocess, 42.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 43.1ms
# Speed: 2.1ms preprocess, 43.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 2 persons, 1 chair, 45.6ms
# Speed: 2.0ms preprocess, 45.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 2 chairs, 1 bed, 45.1ms
# Speed: 2.0ms preprocess, 45.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 bed, 48.7ms
# Speed: 2.0ms preprocess, 48.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 2 chairs, 1 bed, 63.9ms
# Speed: 2.0ms preprocess, 63.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
# Warning: bed Approaching! Proximity: 0.83
#
# 0: 480x640 1 person, 1 chair, 1 bed, 50.3ms
# Speed: 2.5ms preprocess, 50.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 1 bed, 46.5ms
# Speed: 1.5ms preprocess, 46.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 44.1ms
# Speed: 2.5ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 47.7ms
# Speed: 2.0ms preprocess, 47.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: person Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 1 bed, 42.5ms
# Speed: 2.0ms preprocess, 42.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 44.4ms
# Speed: 2.0ms preprocess, 44.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 46.1ms
# Speed: 2.0ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 bed, 52.6ms
# Speed: 2.0ms preprocess, 52.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bed Approaching! Proximity: 0.75
#
# 0: 480x640 1 person, 1 chair, 1 bed, 47.0ms
# Speed: 1.0ms preprocess, 47.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
#
# 0: 480x640 1 person, 1 chair, 1 bed, 44.6ms
# Speed: 2.0ms preprocess, 44.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 chair, 1 bed, 46.1ms
# Speed: 2.0ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 chairs, 1 bed, 71.6ms
# Speed: 2.0ms preprocess, 71.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: bed Approaching! Proximity: 0.80
#
# 0: 480x640 1 person, 2 chairs, 1 bed, 41.9ms
# Speed: 2.0ms preprocess, 41.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Warning: chair Approaching! Proximity: 1.00
# Live feed interrupted.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Cleanup: release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
print("Resources released successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Cleanup: release the webcam and close all OpenCV windows
# ----> 2 cap.release()
#       3 cv2.destroyAllWindows()
#       4 print("Resources released successfully.")
#
# NameError: name 'cap' is not defined
